# %% [markdown]
# #Exploración Inicial de los Datos
#
# ####**Autor:** Daniela Zabaleta Benitez
# ####**Fecha:** 19/08/2025
# ####**Descripción:**  Notebook para presentar un exploración inicial para entender los datos de la prueba técnica #2, se incluye posibles limpiezas, análisis de datos y visualizaciones básicas.

# %% [markdown]
# #Librerias

# %%
import pandas as pd #Manipulacion dataframes

# %% [markdown]
# #Cargar los datos

# %%
#Ruta archivos
# %cd /content/drive/MyDrive/Colab Notebooks/Prueba Técnica Cientifico de Datos/Prueba tecnica 2
# Out:
# /content/drive/MyDrive/Colab Notebooks/Prueba Técnica Cientifico de Datos/Prueba tecnica 2

# %%
df = pd.read_excel('Datos/sentencias_pasadas.xlsx')
df.head(10)
# Out:
#     #  Relevancia Providencia  Tipo Fecha Sentencia  \
# 0   1   966965.00    T-185/22   NaN      2022-05-31
# 1   3   963168.00    T-356/21   NaN      2021-10-15
# 2   5   956201.00    T-351/22   NaN      2022-10-07
# 3   6   955889.00    T-246/21   NaN      2021-07-29
# 4   7   955787.00   T-245A/22   NaN      2022-07-01
# 5   8   954029.00    T-190/24   NaN      2024-05-23
# 6   9   947406.00    T-394/24   NaN      2024-09-19
# 7  10   945053.00    T-155/19   NaN      2019-04-04
# 8  11   943156.00    T-339/22   NaN      2022-09-28
# 9  14      939.17    T-281/21   NaN      2021-08-23
#
#                                       Tema - subtema  \
# 0                                                NaN
# 1  ACCIÓN DE TUTELA PARA PROTEGER EL DERECHO A LA...
# 2  ACCIÓN DE TUTELA PARA PROTEGER EL DERECHO A LA...
# 3  ACCION DE TUTELA PARA PROTEGER EL DERECHO A LA...
# 4  ACCION DE TUTELA-Inexistencia de hecho superad...
# 5                                                NaN
# ...

# %% [markdown]
# #Exploración inicial
#
# ####Análisis exploratorio completo

# %%
#Información general del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 329 entries, 0 to 328
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   #                329 non-null    int64
#  1   Relevancia       329 non-null    float64
#  2   Providencia      329 non-null    object
#  3   Tipo             0 non-null      float64
#  4   Fecha Sentencia  329 non-null    datetime64[ns]
#  5   Tema - subtema   237 non-null    object
#  6   resuelve         329 non-null    object
#  7   sintesis         329 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 20.7+ KB

# %%
#Cantidad de valores nulos por columna
df.isnull().sum()
# Out:
# #                    0
# Relevancia           0
# Providencia          0
# Tipo               329
# Fecha Sentencia      0
# Tema - subtema      92
# resuelve             0
# sintesis             0
# dtype: int64

# %%
df.columns
# Out:
# Index(['#', 'Relevancia', 'Providencia', 'Tipo', 'Fecha Sentencia',
#        'Tema - subtema', 'resuelve', 'sintesis'],
#       dtype='object')

# %%
df.shape
# Out:
# (329, 8)

# %%
print("Fecha min:",df['Fecha Sentencia'].min())
print("Fecha max:",df['Fecha Sentencia'].max())
# Out:
# Fecha min: 2019-02-01 00:00:00
# Fecha max: 2024-11-13 00:00:00

# %% [markdown]
# #Observaciones Iniciales
#
# ####El DataFrame cuenta con 8 columnas y 329 filas, la columna 'tipo' no contiene información por lo que no aporta información.
# ####La mayoria de columnas pueden ser cadenas de texto al ser de tipo objeto.
